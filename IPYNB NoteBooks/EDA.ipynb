# %%
# The objective of this notebook is to filter the data set to only the Consumables we are interested in
# right now the data set is too large and we are only interested in a few consumables
# we will filter the data set to only the consumables we are interested in and then save the data set to a new file

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
import os
import sys

# %%
# Load the data set
marketable_conusmables = pd.read_csv('..\\data\\marketable_consumables.csv')
marketable_conusmables.head()
# Out:
#      ID                  Icon         Name         Url UrlType     _  _Score
# 0  4551  /i/020000/020601.png       Potion  /Item/4551    Item  item       0
# 1  4552  /i/020000/020602.png    Hi-Potion  /Item/4552    Item  item       0
# 2  4553  /i/020000/020603.png  Mega-Potion  /Item/4553    Item  item       0
# 3  4554  /i/020000/020603.png     X-Potion  /Item/4554    Item  item       0
# 4  4555  /i/020000/020621.png        Ether  /Item/4555    Item  item       0

# %%
# Lets reduce this list to the 5 items we are interested in
# "Grade 8 Tincture" will be the filter we use to reduce the data set
# we will only keep the rows that have "Grade 8 Tincture" in the name
tinctures = marketable_conusmables[marketable_conusmables['Name'].str.contains('Grade 8 Tincture')]
tinctures
# Out:
#          ID                  Icon                              Name  \
# 2206  39727  /i/020000/020710.png      Grade 8 Tincture of Strength
# 2207  39728  /i/020000/020709.png     Grade 8 Tincture of Dexterity
# 2208  39729  /i/020000/020707.png      Grade 8 Tincture of Vitality
# 2209  39730  /i/020000/020706.png  Grade 8 Tincture of Intelligence
# 2210  39731  /i/020000/020708.png          Grade 8 Tincture of Mind
#
#               Url UrlType     _  _Score
# 2206  /Item/39727    Item  item       0
# 2207  /Item/39728    Item  item       0
# 2208  /Item/39729    Item  item       0
# 2209  /Item/39730    Item  item       0
# 2210  /Item/39731    Item  item       0

# %%
# Save the data set to a new file
tinctures.to_csv('..\\data\\tinctures.csv', index=False)

# %%
# Now we have a new data set that only contains the consumables we are interested in
# we can import all the market data from the game and then filter it to only the consumables we are interested in
# this will make the data set smaller and easier to work with

all_market_data = pd.read_csv('..\\data\\all_results_1_year.csv')
all_market_data.head()
# Out:
#    itemID  lastUploadTime                                            entries  \
# 0    4551   1710803938756  [{'hq': False, 'pricePerUnit': 2, 'quantity': ...
# 1    4552   1710807769958  [{'hq': False, 'pricePerUnit': 25, 'quantity':...
# 2    4553   1710864064227  [{'hq': False, 'pricePerUnit': 999, 'quantity'...
# 3    4554   1710864071158  [{'hq': True, 'pricePerUnit': 299, 'quantity':...
# 4    4555   1710806562911  [{'hq': False, 'pricePerUnit': 10, 'quantity':...
#
#    dcName  regularSaleVelocity  nqSaleVelocity  hqSaleVelocity  \
# 0  Aether            420.42856       185.28572      235.142850
# 1  Aether            510.57144       268.14285      242.428570
# 2  Aether            346.14285        64.00000      282.142850
# 3  Aether            226.00000        35.00000      191.000000
# 4  Aether            153.57143       150.14285        3.428571
#
#    stackSizeHistogram.1  stackSizeHistogram.2  stackSizeHistogram.3  ...  \
# 0                 443.0                 404.0                 629.0  ...
# 1                 597.0                 393.0                1284.0  ...
# 2                 583.0                 580.0                 952.0  ...
# 3                 634.0                 697.0                 977.0  ...
# 4                 365.0                 186.0                 524.0  ...
#
#    stackSizeHistogramHQ.99  stackSizeHistogram.97  stackSizeHistogramNQ.76  \
# 0                    316.0                    NaN                      NaN
# 1                    460.0                    7.0                      2.0
# 2                    343.0                    4.0                      NaN
# 3                    215.0                    4.0                      NaN
# 4                     32.0                    NaN                      3.0
#
#    stackSizeHistogramNQ.79  stackSizeHistogramNQ.85  stackSizeHistogramNQ.88  \
# 0                      NaN                      NaN                      NaN
# 1                      4.0                      1.0                      3.0
# 2                      1.0                      1.0                      3.0
# 3                      1.0                      3.0                      1.0
# 4                      NaN                      1.0                      1.0
#
#    stackSizeHistogramNQ.97  stackSizeHistogramHQ.89  stackSizeHistogramHQ.97  \
# 0                      NaN                      NaN                      NaN
# 1                      3.0                      9.0                      4.0
# 2                      NaN                      NaN                      4.0
# 3                      3.0                      2.0                      1.0
# 4                      NaN                      NaN                      NaN
#
#    stackSizeHistogramHQ.92
# 0                      NaN
# 1                      NaN
# 2                      3.0
# 3                      1.0
# 4                      NaN
#
# [5 rows x 304 columns]

# %%
# normalize the entries column at 0 index for all_market_data
normal = all_market_data.head(1)
normal
# Out:
#    itemID  lastUploadTime                                            entries  \
# 0    4551   1710803938756  [{'hq': False, 'pricePerUnit': 2, 'quantity': ...
#
#    dcName  regularSaleVelocity  nqSaleVelocity  hqSaleVelocity  \
# 0  Aether            420.42856       185.28572       235.14285
#
#    stackSizeHistogram.1  stackSizeHistogram.2  stackSizeHistogram.3  ...  \
# 0                 443.0                 404.0                 629.0  ...
#
#    stackSizeHistogramHQ.99  stackSizeHistogram.97  stackSizeHistogramNQ.76  \
# 0                    316.0                    NaN                      NaN
#
#    stackSizeHistogramNQ.79  stackSizeHistogramNQ.85  stackSizeHistogramNQ.88  \
# 0                      NaN                      NaN                      NaN
#
#    stackSizeHistogramNQ.97  stackSizeHistogramHQ.89  stackSizeHistogramHQ.97  \
# 0                      NaN                      NaN                      NaN
#
#    stackSizeHistogramHQ.92
# 0                      NaN
#
# [1 rows x 304 columns]

# %%
results = pd.DataFrame.from_records(json.loads(normal['entries'][0]))
results
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 results = pd.DataFrame.from_records(json.loads(normal['entries'][0]))
#       2 results
#
# File d:\Anaconda\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File d:\Anaconda\Lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File d:\Anaconda\Lib\json\decoder.py:353, in JSONDecoder.raw_decode(self, s, idx)
#     344 """Decode a JSON document from ``s`` (a ``str`` beginning with
#     345 a JSON document) and return a 2-tuple of the Python
#     346 representation and the index in ``s`` where the document ended.
#    (...)
#     350
#     351 """
#     352 try:
# --> 353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
#     355     raise JSONDecodeError("Expecting value", s, err.value) from None
#
# JSONDecodeError: Expecting property name enclosed in double quotes: line 1 column 3 (char 2)

# %%
# Now we will filter the data set to only the consumables we are interested in
# we will use the "tinctures" data set to filter the "all_market_data" data set
# all_market_data does not contain the "Name" column so we will need to merge the two data sets on the "ItemID" column and "ID" column

# Merge the two data sets
tincture_market_data = pd.merge(tinctures, all_market_data, left_on='ID', right_on='itemID', how='inner')
tincture_market_data
# Out:
#       ID                  Icon                              Name          Url  \
# 0  39727  /i/020000/020710.png      Grade 8 Tincture of Strength  /Item/39727
# 1  39728  /i/020000/020709.png     Grade 8 Tincture of Dexterity  /Item/39728
# 2  39729  /i/020000/020707.png      Grade 8 Tincture of Vitality  /Item/39729
# 3  39730  /i/020000/020706.png  Grade 8 Tincture of Intelligence  /Item/39730
# 4  39731  /i/020000/020708.png          Grade 8 Tincture of Mind  /Item/39731
#
#   UrlType     _  _Score  itemID  lastUploadTime  \
# 0    Item  item       0   39727   1710880895885
# 1    Item  item       0   39728   1710881460403
# 2    Item  item       0   39729   1710807960305
# 3    Item  item       0   39730   1710880803136
# 4    Item  item       0   39731   1710880809452
#
#                                              entries  ...  \
# 0  [{'hq': True, 'pricePerUnit': 2790, 'quantity'...  ...
# 1  [{'hq': True, 'pricePerUnit': 2853, 'quantity'...  ...
# 2  [{'hq': True, 'pricePerUnit': 2974, 'quantity'...  ...
# 3  [{'hq': True, 'pricePerUnit': 2867, 'quantity'...  ...
# 4  [{'hq': True, 'pricePerUnit': 2995, 'quantity'...  ...
#
#   stackSizeHistogramHQ.99  stackSizeHistogram.97  stackSizeHistogramNQ.76  \
# 0                 89546.0                   23.0                      1.0
# 1                 37165.0                   23.0                      NaN
# 2                    64.0                    NaN                      NaN
# 3                 32106.0                   12.0                      NaN
# 4                 34881.0                    9.0                      NaN
#
#    stackSizeHistogramNQ.79  stackSizeHistogramNQ.85  stackSizeHistogramNQ.88  \
# 0                      1.0                      1.0                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      1.0                      1.0                      NaN
# 4                      NaN                      NaN                      NaN
#
#    stackSizeHistogramNQ.97  stackSizeHistogramHQ.89  stackSizeHistogramHQ.97  \
# 0                      1.0                     19.0                     22.0
# 1                      1.0                     20.0                     22.0
# 2                      NaN                      1.0                      NaN
# 3                      1.0                     11.0                     11.0
# 4                      NaN                      8.0                      9.0
#
#    stackSizeHistogramHQ.92
# 0                     17.0
# 1                      6.0
# 2                      NaN
# 3                     10.0
# 4                      7.0
#
# [5 rows x 311 columns]

# %%
# Save the data set to a new file
tincture_market_data.to_csv('..\\data\\tincture_market_data.csv', index=False)

# %%
# For every single index in the "tincture_market_data" df, we will create a new df that contains the market data for that item

strength_tincture = tincture_market_data[tincture_market_data['Name'].str.contains('Strength')]
dexterity_tincture = tincture_market_data[tincture_market_data['Name'].str.contains('Dexterity')]
intelligence_tincture = tincture_market_data[tincture_market_data['Name'].str.contains('Intelligence')]
mind_tincture = tincture_market_data[tincture_market_data['Name'].str.contains('Mind')]
vitality_tincture = tincture_market_data[tincture_market_data['Name'].str.contains('Vitality')]

# %%
strength_tincture
# Out:
#       ID                  Icon                          Name          Url  \
# 0  39727  /i/020000/020710.png  Grade 8 Tincture of Strength  /Item/39727
#
#   UrlType     _  _Score  itemID  lastUploadTime  \
# 0    Item  item       0   39727   1710880895885
#
#                                              entries  ...  \
# 0  [{'hq': True, 'pricePerUnit': 2790, 'quantity'...  ...
#
#   stackSizeHistogramHQ.99  stackSizeHistogram.97  stackSizeHistogramNQ.76  \
# 0                 89546.0                   23.0                      1.0
#
#    stackSizeHistogramNQ.79  stackSizeHistogramNQ.85  stackSizeHistogramNQ.88  \
# 0                      1.0                      1.0                      NaN
#
#    stackSizeHistogramNQ.97  stackSizeHistogramHQ.89  stackSizeHistogramHQ.97  \
# 0                      1.0                     19.0                     22.0
#
#    stackSizeHistogramHQ.92
# 0                     17.0
#
# [1 rows x 311 columns]

# %%
strength_tincture.columns
# Out:
# Index(['ID', 'Icon', 'Name', 'Url', 'UrlType', '_', '_Score', 'itemID',
#        'lastUploadTime', 'entries',
#        ...
#        'stackSizeHistogramHQ.99', 'stackSizeHistogram.97',
#        'stackSizeHistogramNQ.76', 'stackSizeHistogramNQ.79',
#        'stackSizeHistogramNQ.85', 'stackSizeHistogramNQ.88',
#        'stackSizeHistogramNQ.97', 'stackSizeHistogramHQ.89',
#        'stackSizeHistogramHQ.97', 'stackSizeHistogramHQ.92'],
#       dtype='object', length=311)
